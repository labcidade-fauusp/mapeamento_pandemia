# %% [markdown]
# # Demanda SPTrans
# Este jupyter notebook baixa dados de demanda das linhas da SPTrans

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import io
import os

# %%
TIME_STEP = 15

def getTimeRangeTags(datestring, dateformat='%Y-%m-%d', zerodate = datetime(2020,1,1)):
    '''
    Returns the sequetial number and start date of the week from a given datestring
    '''
    datedelta = datetarget - zerodate
    deltadays = datedelta.days
    timetag = (deltadays//TIME_STEP) + 1
    refday = zerodate + timedelta(days=(timetag-1)*TIME_STEP)
    
    d = {'text':f'{("000"+str(timetag))[-3:]} ({datetarget.year})',
         'refday':refday}
    return d

def is_business_day(date):
    return bool(len(pd.bdate_range(date, date)))

# %%
url = 'https://www.prefeitura.sp.gov.br/cidade/secretarias/upload/{0}.xls'

# %%
meses ={
    1:'JAN',
    2:'FEV',
    3:'MAR',
    4:'ABR',
    5:'MAI',
    6:'JUN',
    7:'JUL',
    8:'AGO',
    9:'SET',
    10:'OUT',
    11:'NOV',
    12:'DEZ'
}

sdate = datetime(2019,1,1)   # start date
edate = datetime(2022,10,31)   # end date

target_dates = list(pd.date_range(sdate,edate-timedelta(days=1),freq='d'))
target_dates = [f'{("00"+str(d.day))[-2:]}{meses[d.month]}{d.year}' for d in target_dates]

# %%
### Download files

for date in target_dates:
    try:
        filename = f'sptrans/{date}.xls'
        if not os.path.isfile(filename):
            r =requests.get(url.format(date))
            with open(filename, 'wb') as f:
                f.write(r.content)
    except:
        print(f'Erro em {date}')
        continue

# %%
df = pd.DataFrame()

for date in target_dates:
    try:
        filename = f'sptrans/{date}.xls'
        df_temp = pd.read_excel(filename, skiprows=2)
        df = pd.concat([df, df_temp])
    except:
        print(date)
# Out:
# 01JAN2019
# 02JAN2019
# 03JAN2019
# 04JAN2019
# 05JAN2019
# 06JAN2019
# 07JAN2019
# 08JAN2019
# 09JAN2019
# 10JAN2019
# 11JAN2019
# 12JAN2019
# 13JAN2019
# 14JAN2019
# 15JAN2019
# 16JAN2019
# 17JAN2019
# 18JAN2019
# 19JAN2019
# 20JAN2019
# 21JAN2019
# 22JAN2019
# 23JAN2019
# 24JAN2019
# 25JAN2019
# 26JAN2019
# 27JAN2019
# 28JAN2019
# 29JAN2019
# 30JAN2019
# 31JAN2019
# 01FEV2019
# 02FEV2019
# 03FEV2019
# 04FEV2019
# 05FEV2019
# 06FEV2019
# 07FEV2019
# 08FEV2019
# 09FEV2019
# 10FEV2019
# 11FEV2019
# 12FEV2019
# 13FEV2019
# 14FEV2019
# 15FEV2019
# 16FEV2019
# 17FEV2019
# 18FEV2019
# 19FEV2019
# 20FEV2019
# 21FEV2019
# 22FEV2019
# 23FEV2019
# 24FEV2019
# 25FEV2019
# 26FEV2019
# 27FEV2019
# 28FEV2019

# %%
df['Data'] = df['Data'].apply(lambda x: x if isinstance(x, pd.Timestamp) else datetime. strptime(x, '%d/%m/%Y'))
df['Dia_útil'] = df['Data'].apply(is_business_day)
df['ano-mes'] = df['Data'].apply(lambda x: f'{x.year}' + '-' + (f'0{x.month}'[-2:]))
df['CodLinha'] = df['Linha'].apply(lambda x: x.split(' ')[0])
df_sptrans = df.drop_duplicates()
df_sptrans.head()
# Out:
#         Data       Tipo    Area     Empresa  \
# 0 2019-03-01  CONCESSAO  AREA 1  GATO PRETO
# 1 2019-03-01  CONCESSAO  AREA 1  GATO PRETO
# 2 2019-03-01  CONCESSAO  AREA 1  GATO PRETO
# 3 2019-03-01  CONCESSAO  AREA 1  GATO PRETO
# 4 2019-03-01  CONCESSAO  AREA 1  GATO PRETO
#
#                                      Linha  Passageiros Pagtes Em Dinheiro  \
# 0     N10511 - TERM CACHOEIRINHA/TERM LAPA                              14
# 1  N14311 - METRO BARRA FUNDA/MORRO GRANDE                               4
# 2  800001 - TERM LAPA/PCA RAMOS DE AZEVEDO                             408
# 3         830001 - TERM PIRITUBA/TERM LAPA                              43
# 4             853810 - VILA IARA/PAISSANDU                             130
#
#    Passageiros Pagtes Comum  Passageiros Pgts Bu Comum M  \
# 0                      47.0                            7
# 1                       8.0                            4
# 2                    1217.0                          193
# 3                     159.0                           21
# 4                     372.0                           34
#
#    Passageiros Pagtes Estudante  Passageiros Pgts Bu Est Mensal  ...  \
# 0                             1                               0  ...
# 1                             3                               0  ...
# 2                           142                               0  ...
# 3                            12                               0  ...
# 4                            43                               0  ...
#
#    Passageiros Int Ônibus->Ônibus  Passageiros Com Gratuidade  \
# 0                             122                          23
# 1                              13                           5
# 2                            2140                        1535
# 3                             330                         155
# 4                             322                         323
#
#    Passageiros Com Gratuidade Est  Tot Passageiros Transportados  \
# 0                               6                            269
# 1                               1                             74
# 2                             301                           7271
# 3                              53                           1014
# 4                              87                           1727
#
#    Passageiros Comum e VT  Grupo  Lote  Dia_útil  ano-mes  CodLinha
# 0                     NaN    NaN   NaN      True  2019-03    N10511
# 1                     NaN    NaN   NaN      True  2019-03    N14311
# 2                     NaN    NaN   NaN      True  2019-03    800001
# 3                     NaN    NaN   NaN      True  2019-03    830001
# 4                     NaN    NaN   NaN      True  2019-03    853810
#
# [5 rows x 25 columns]

# %%
df_mean = df_sptrans.query('Dia_útil == True').sort_values(by='ano-mes').fillna(0).pivot_table(index='CodLinha', columns = 'ano-mes', values='Tot Passageiros Transportados', aggfunc='mean').fillna(0).reset_index()
df_mean.to_csv('agregado ônibus.csv', index=False)

# %%
df_all = df_sptrans.query('Dia_útil == True').sort_values(by='ano-mes').fillna(0).pivot_table(index= ['Data','ano-mes'], values='Tot Passageiros Transportados', aggfunc='sum').reset_index()\
                    .pivot_table(index= 'ano-mes', values='Tot Passageiros Transportados', aggfunc='mean').fillna(0).reset_index()
df_all
# Out:
#     ano-mes  Tot Passageiros Transportados
# 0   2019-03                   8.327065e+06
# 1   2019-04                   8.564868e+06
# 2   2019-05                   8.990493e+06
# 3   2019-06                   8.322663e+06
# 4   2019-07                   7.725656e+06
# 5   2019-08                   8.518773e+06
# 6   2019-09                   8.749808e+06
# 7   2019-10                   8.961552e+06
# 8   2019-11                   8.281881e+06
# 9   2019-12                   7.453863e+06
# 10  2020-01                   7.196222e+06
# 11  2020-02                   7.845873e+06
# 12  2020-03                   6.143414e+06
# 13  2020-04                   2.568516e+06
# 14  2020-05                   2.612752e+06
# 15  2020-06                   3.368342e+06
# 16  2020-07                   4.023172e+06
# 17  2020-08                   4.556853e+06
# 18  2020-09                   4.563946e+06
# 19  2020-10                   4.867426e+06
# 20  2020-11                   5.130456e+06
# 21  2020-12                   4.825464e+06
# 22  2021-01                   5.139294e+06
# 23  2021-02                   5.215821e+06
# 24  2021-03                   4.414006e+06
# 25  2021-04                   4.287543e+06
# 26  2021-05                   4.577487e+06
# 27  2021-06                   4.482285e+06
# 28  2021-07                   4.567877e+06
# 29  2021-08                   5.512023e+06
# 30  2021-09                   5.555022e+06
# 31  2021-10                   5.336378e+06
# 32  2021-11                   5.371004e+06
# 33  2021-12                   5.688496e+06
# 34  2022-01                   4.735342e+06
# 35  2022-02                   5.888900e+06
# 36  2022-03                   6.395703e+06
# 37  2022-04                   6.439465e+06
# 38  2022-05                   6.792730e+06
# 39  2022-06                   6.112108e+06
# 40  2022-07                   6.126694e+06
# 41  2022-08                   6.916639e+06
# 42  2022-09                   6.640653e+06
# 43  2022-10                   6.831063e+06
